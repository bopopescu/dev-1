# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing, cross_validation, neighbors, svm
from sklearn.ensemble import RandomForestClassifier, BaggingClassifier, VotingClassifier, GradientBoostingClassifier, ExtraTreesClassifier
from sklearn.cluster import KMeans
from sklearn.metrics import accuracy_score, mean_squared_error
DIR_DATA = "data"
DIR_PROCESSED = "processed"
LABEL = "rating"
NON_PREDICTORS = [LABEL]#, "name","anime_id"]
CV_FOLDS = 5

# %%
animes = pd.read_csv(DIR_DATA + '/anime.csv')
ratings = pd.read_csv(DIR_DATA + '/rating.csv')

label = animes.rating

# TODO: Turn type, genre into class
# TODO: Get things with similar names classified together

labeled_ratings = ratings[ratings["rating"] != -1][:1000]

# %%
animes.head()
# Out:
#    anime_id                              name  \
# 0     32281                    Kimi no Na wa.
# 1      5114  Fullmetal Alchemist: Brotherhood
# 2     28977                          Gintama°
# 3      9253                       Steins;Gate
# 4      9969                     Gintama&#039;
#
#                                                genre   type episodes  rating  \
# 0               Drama, Romance, School, Supernatural  Movie        1    9.37
# 1  Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64    9.26
# 2  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.25
# 3                                   Sci-Fi, Thriller     TV       24    9.17
# 4  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.16
#
#    members
# 0   200630
# 1   793665
# 2   114262
# 3   673572
# 4   151266

# %%
ratings.tail()
# Out:
#          user_id  anime_id  rating
# 7813732    73515     16512       7
# 7813733    73515     17187       9
# 7813734    73515     22145      10
# 7813735    73516       790       9
# 7813736    73516      8074       9

# %%
# TODO: Get user_id, previous rankings

# %%
def predict_naive(ratings, animes):
  prediction = []
  for anime_id in ratings[ratings["rating"] != -1].anime_id:
    prediction.append(round(animes[animes.anime_id == anime_id].rating.item()))
  return prediction

# %%
predictions = predict_naive(labeled_ratings,animes)

# %%
animes[animes.anime_id == 8074].rating
# Out:
# 1709    7.46
# Name: rating, dtype: float64

# %%
print(mean_squared_error(predictions, labeled_ratings.rating.tolist()))
# Out:
# 7.518

# %%
ratings[ratings["rating"] != -1].ratings.item()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-49-34708c7b6794> in <module>()
# ----> 1 ratings[ratings["rating"] != -1].ratings.item()
#
# /home/altock/anaconda3/envs/py35/lib/python3.5/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    2742             if name in self._info_axis:
#    2743                 return self[name]
# -> 2744             return object.__getattribute__(self, name)
#    2745
#    2746     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'ratings'

# %%
list(predictions)
# Out:
# [7.46,
#  7.7,
#  7.83,
#  7.87,
#  8.46,
#  7.81,
#  7.83,
#  8.56,
#  8.93,
#  6.72,
#  7.38,
#  7.74,
#  7.43,
#  7.89,
#  8.32,
#  7.05,
#  6.93,
#  7.1,
#  7.25,
#  7.41,
#  7.37,
#  7.4,
#  8.71,
#  7.2,
#  8.1,
#  7.47,
#  8.15,
#  7.02,
#  7.06,
#  7.34,
#  8.08,
#  7.1,
#  9.26,
#  7.72,
#  7.14,
#  8.22,
#  7.48,
#  7.13,
#  7.46,
#  6.78,
#  7.5,
#  7.81,
#  6.94,
#  7.92,
#  8.62,
#  8.61,
#  7.32,
#  7.88,
#  7.03,
#  7.88,
#  7.83,
#  7.62,
#  8.46,
#  6.68,
#  8.17,
#  6.78,
#  7.68,
#  8.24,
#  8.54,
#  7.06,
#  8.35,
#  8.58,
#  8.18,
#  8.14,
#  7.11,
#  8.5,
#  7.54,
#  3.82,
#  8.47,
#  7.0,
#  7.94,
#  8.17,
#  8.68,
#  6.33,
#  7.35,
#  7.84,
#  8.42,
#  8.07,
#  6.25,
#  7.66,
#  7.7,
#  7.66,
#  6.32,
#  8.42,
#  8.62,
#  7.65,
#  7.55,
#  7.52,
#  7.88,
#  8.61,
#  8.33,
#  7.63,
#  8.45,
#  8.93,
#  7.71,
#  8.65,
#  7.87,
#  8.32,
#  8.08,
#  7.74,
#  8.24,
#  7.81,
#  8.04,
#  8.06,
#  8.32,
#  8.43,
#  8.15,
#  8.4,
#  6.8,
#  7.68,
#  7.52,
#  7.73,
#  8.48,
#  8.41,
#  8.33,
#  8.41,
#  7.8,
#  7.38,
#  7.6,
#  8.56,
#  7.1,
#  8.23,
#  8.12,
#  7.28,
#  7.36,
#  7.35,
#  8.93,
#  8.5,
#  8.16,
#  6.72,
#  8.18,
#  7.76,
#  6.69,
#  8.77,
#  6.84,
#  7.89,
#  7.66,
#  8.83,
#  8.39,
#  8.28,
#  8.05,
#  7.95,
#  7.41,
#  6.81,
#  6.99,
#  7.42,
#  7.47,
#  7.74,
#  7.57,
#  7.35,
#  8.47,
#  6.73,
#  7.17,
#  7.42,
#  7.18,
#  7.57,
#  7.23,
#  6.9,
#  7.03,
#  7.85,
#  7.43,
#  7.66,
#  7.87,
#  7.29,
#  7.89,
#  7.72,
#  7.16,
#  6.55,
#  8.32,
#  8.15,
#  8.11,
#  7.65,
#  6.99,
#  7.24,
#  7.11,
#  7.72,
#  7.7,
#  9.04,
#  6.99,
#  7.03,
#  6.75,
#  7.46,
#  7.25,
#  7.13,
#  7.62,
#  8.4,
#  7.97,
#  8.03,
#  8.26,
#  7.37,
#  6.91,
#  8.71,
#  8.25,
#  7.2,
#  7.45,
#  7.02,
#  6.77,
#  7.37,
#  8.1,
#  7.47,
#  7.73,
#  7.87,
#  7.6,
#  6.96,
#  8.23,
#  7.95,
#  7.35,
#  6.95,
#  8.11,
#  8.44,
#  6.96,
#  7.6,
#  6.99,
#  7.81,
#  7.4,
#  7.27,
#  8.43,
#  7.62,
#  7.43,
#  7.86,
#  7.87,
#  8.03,
#  7.0,
#  6.38,
#  7.18,
#  7.61,
#  7.23,
#  7.14,
#  8.03,
#  7.34,
#  6.74,
#  7.82,
#  8.08,
#  7.44,
#  8.26,
#  7.6,
#  7.35,
#  7.56,
#  7.38,
#  6.76,
#  7.4,
#  7.24,
#  8.45,
#  7.43,
#  7.92,
#  6.96,
#  7.69,
#  6.48,
#  6.58,
#  6.62,
#  7.02,
#  8.41,
#  7.33,
#  7.52,
#  8.75,
#  7.61,
#  7.19,
#  6.86,
#  7.51,
#  7.87,
#  8.3,
#  7.68,
#  7.18,
#  7.03,
#  8.19,
#  7.19,
#  7.5,
#  7.83,
#  8.01,
#  6.25,
#  7.39,
#  8.39,
#  6.31,
#  8.22,
#  8.38,
#  6.74,
#  6.64,
#  7.82,
#  7.16,
#  7.21,
#  6.87,
#  7.09,
#  7.71,
#  7.71,
#  8.35,
#  8.2,
#  7.7,
#  7.38,
#  8.14,
#  7.18,
#  7.63,
#  7.46,
#  7.01,
#  6.43,
#  7.86,
#  8.04,
#  7.36,
#  7.47,
#  7.98,
#  7.95,
#  5.9,
#  7.71,
#  7.49,
#  7.67,
#  7.12,
#  7.85,
#  7.61,
#  6.61,
#  9.17,
#  7.4,
#  7.2,
#  7.33,
#  7.8,
#  6.56,
#  5.79,
#  7.92,
#  6.69,
#  9.16,
#  7.32,
#  8.62,
#  7.66,
#  8.53,
#  8.12,
#  7.16,
#  7.53,
#  7.89,
#  8.56,
#  7.44,
#  6.74,
#  7.57,
#  7.64,
#  7.49,
#  7.3,
#  7.98,
#  7.62,
#  7.41,
#  7.57,
#  7.78,
#  7.42,
#  8.46,
#  6.85,
#  7.69,
#  8.07,
#  7.51,
#  7.77,
#  7.67,
#  7.7,
#  7.53,
#  8.61,
#  7.7,
#  7.55,
#  7.83,
#  7.62,
#  7.21,
#  7.25,
#  8.02,
#  8.35,
#  6.57,
#  8.23,
#  8.17,
#  8.59,
#  7.95,
#  6.19,
#  7.4,
#  6.96,
#  6.37,
#  7.28,
#  7.47,
#  7.35,
#  7.32,
#  7.25,
#  6.9,
#  7.44,
#  7.37,
#  6.85,
#  7.79,
#  5.62,
#  7.88,
#  7.43,
#  7.82,
#  8.4,
#  7.82,
#  7.25,
#  7.56,
#  6.78,
#  7.77,
#  8.0,
#  7.73,
#  8.24,
#  7.63,
#  7.67,
#  6.93,
#  8.51,
#  7.95,
#  7.32,
#  8.12,
#  7.7,
#  8.19,
#  8.14,
#  7.46,
#  7.85,
#  9.1,
#  7.36,
#  9.11,
#  7.64,
#  7.87,
#  6.35,
#  7.54,
#  6.91,
#  6.75,
#  7.97,
#  7.64,
#  8.03,
#  7.8,
#  8.32,
#  7.65,
#  7.49,
#  7.35,
#  7.4,
#  7.49,
#  6.01,
#  7.39,
#  8.3,
#  7.29,
#  8.35,
#  7.27,
#  8.58,
#  8.18,
#  6.63,
#  7.39,
#  8.14,
#  7.47,
#  7.55,
#  7.67,
#  7.17,
#  6.46,
#  7.04,
#  7.45,
#  7.92,
#  7.1,
#  6.13,
#  6.98,
#  8.5,
#  7.69,
#  7.88,
#  8.16,
#  7.47,
#  6.82,
#  7.44,
#  7.31,
#  7.56,
#  7.61,
#  7.6,
#  7.07,
#  8.25,
#  7.61,
#  6.62,
#  7.91,
#  7.04,
#  7.5,
#  7.55,
#  8.36,
#  7.0,
#  7.52,
#  8.68,
#  6.18,
#  6.55,
#  8.47,
#  6.49,
#  7.75,
#  7.08,
#  7.2,
#  6.27,
#  7.86,
#  7.94,
#  7.84,
#  7.28,
#  8.17,
#  7.59,
#  6.92,
#  8.68,
#  7.41,
#  7.89,
#  7.76,
#  7.44,
#  7.84,
#  7.47,
#  8.25,
#  6.54,
#  7.42,
#  7.18,
#  7.47,
#  6.75,
#  7.22,
#  7.96,
#  7.23,
#  7.7,
#  7.9,
#  7.09,
#  6.33,
#  7.33,
#  6.19,
#  7.21,
#  8.16,
#  7.09,
#  7.37,
#  7.68,
#  7.84,
#  8.07,
#  8.59,
#  8.5,
#  5.54,
#  8.15,
#  7.11,
#  7.69,
#  8.92,
#  7.69,
#  8.24,
#  6.47,
#  7.29,
#  8.42,
#  8.31,
#  7.79,
#  7.2,
#  6.63,
#  7.59,
#  7.7,
#  6.44,
#  7.76,
#  7.43,
#  7.34,
#  7.5,
#  6.78,
#  6.17,
#  6.17,
#  8.6,
#  7.55,
#  7.29,
#  7.52,
#  7.88,
#  8.11,
#  7.91,
#  6.88,
#  8.93,
#  7.97,
#  7.16,
#  6.3,
#  7.01,
#  7.15,
#  7.53,
#  8.04,
#  8.03,
#  8.64,
#  7.52,
#  8.55,
#  7.63,
#  8.04,
#  8.32,
#  7.51,
#  8.45,
#  7.57,
#  7.57,
#  7.78,
#  6.9,
#  8.33,
#  8.48,
#  8.41,
#  8.56,
#  7.87,
#  8.16,
#  6.72,
#  8.18,
#  8.77,
#  7.89,
#  7.64,
#  7.99,
#  6.85,
#  7.87,
#  7.53,
#  7.23,
#  7.03,
#  7.71,
#  7.89,
#  7.87,
#  8.14,
#  7.89,
#  7.19,
#  7.74,
#  8.32,
#  8.06,
#  8.17,
#  7.99,
#  7.13,
#  7.93,
#  7.97,
#  8.03,
#  8.26,
#  7.42,
#  7.37,
#  8.71,
#  7.61,
#  8.83,
#  7.83,
#  7.87,
#  8.41,
#  7.65,
#  7.75,
#  7.35,
#  6.92,
#  8.3,
#  7.74,
#  6.55,
#  8.21,
#  7.32,
#  8.98,
#  7.14,
#  7.84,
#  6.95,
#  7.34,
#  7.82,
#  7.56,
#  8.26,
#  8.53,
#  7.71,
#  7.37,
#  8.14,
#  9.06,
#  7.92,
#  7.24,
#  7.28,
#  7.92,
#  7.69,
#  7.34,
#  6.62,
#  7.72,
#  7.52,
#  7.44,
#  7.51,
#  7.68,
#  6.87,
#  6.73,
#  7.87,
#  8.02,
#  8.37,
#  7.82,
#  6.87,
#  7.63,
#  7.01,
#  7.86,
#  7.36,
#  7.51,
#  7.95,
#  7.49,
#  6.72,
#  7.13,
#  7.84,
#  7.49,
#  7.12,
#  7.56,
#  6.93,
#  7.61,
#  7.2,
#  6.56,
#  6.93,
#  6.97,
#  8.51,
#  7.87,
#  7.26,
#  7.66,
#  6.69,
#  8.12,
#  7.53,
#  7.29,
#  6.58,
#  7.32,
#  7.98,
#  7.68,
#  8.07,
#  7.57,
#  7.12,
#  7.42,
#  6.85,
#  9.13,
#  7.51,
#  7.7,
#  7.55,
#  7.71,
#  7.83,
#  7.62,
#  6.0,
#  7.7,
#  8.31,
#  8.49,
#  8.5,
#  7.4,
#  7.47,
#  6.89,
#  6.43,
#  7.32,
#  7.45,
#  7.37,
#  7.6,
#  7.43,
#  7.82,
#  7.82,
#  7.32,
#  7.25,
#  7.83,
#  7.11,
#  7.95,
#  7.32,
#  7.44,
#  7.7,
#  7.85,
#  7.46,
#  6.91,
#  7.36,
#  6.97,
#  7.87,
#  7.54,
#  7.32,
#  8.03,
#  6.78,
#  7.45,
#  7.8,
#  8.16,
#  7.15,
#  7.06,
#  7.36,
#  8.3,
#  7.29,
#  7.71,
#  7.6,
#  7.15,
#  7.39,
#  8.14,
#  5.81,
#  7.55,
#  6.89,
#  7.67,
#  6.46,
#  7.45,
#  7.1,
#  6.13,
#  7.44,
#  6.98,
#  7.11,
#  7.69,
#  7.88,
#  6.82,
#  7.44,
#  7.31,
#  7.6,
#  7.07,
#  8.23,
#  6.62,
#  7.55,
#  7.91,
#  6.56,
#  7.5,
#  7.55,
#  3.82,
#  6.5,
#  7.52,
#  6.18,
#  8.47,
#  6.83,
#  7.0,
#  7.75,
#  6.53,
#  7.08,
#  7.2,
#  7.94,
#  7.28,
#  7.4,
#  8.17,
#  7.59,
#  6.92,
#  7.41,
#  7.89,
#  5.47,
#  6.54,
#  7.42,
#  7.47,
#  6.75,
#  7.22,
#  6.81,
#  6.9,
#  7.9,
#  7.04,
#  6.81,
#  7.14,
#  6.54,
#  7.35,
#  6.95,
#  7.13,
#  7.41,
#  6.25,
#  7.16,
#  8.01,
#  7.26,
#  7.2,
#  7.11,
#  8.24,
#  7.66,
#  7.47,
#  7.48,
#  6.6,
#  8.42,
#  6.94,
#  7.52,
#  6.75,
#  7.05,
#  7.79,
#  7.57,
#  7.55,
#  7.74,
#  7.56,
#  7.71,
#  6.34,
#  7.71,
#  6.44,
#  7.43,
#  7.34,
#  6.57,
#  6.78,
#  6.17,
#  7.66,
#  6.8,
#  7.55,
#  6.77,
#  7.95,
#  7.5,
#  7.41,
#  7.88,
#  6.37,
#  7.28,
#  7.53,
#  6.98,
#  7.63,
#  6.36,
#  6.88,
#  7.55,
#  7.97,
#  7.8,
#  7.91,
#  7.16,
#  7.49,
#  7.15,
#  6.94,
#  7.15,
#  7.53,
#  8.04,
#  8.82,
#  7.78,
#  7.45,
#  7.39,
#  7.44,
#  7.85,
#  7.13,
#  6.9,
#  6.83,
#  6.61,
#  8.48,
#  7.14,
#  7.32,
#  6.87,
#  8.03,
#  8.12,
#  7.43,
#  8.65,
#  8.17,
#  6.42,
#  6.53,
#  7.17,
#  5.48,
#  7.03,
#  6.66,
#  6.49,
#  7.97,
#  7.85,
#  6.69,
#  7.32,
#  6.42,
#  7.87,
#  6.42,
#  6.45,
#  7.5,
#  7.81,
#  6.88,
#  8.1,
#  7.77,
#  6.16,
#  7.66,
#  6.71,
#  7.81,
#  7.12,
#  7.61,
#  6.68,
#  7.95,
#  7.74,
#  8.22,
#  7.21,
#  7.09,
#  7.13,
#  8.07,
#  7.81,
#  6.97,
#  7.83,
#  8.4,
#  7.54,
#  7.87,
#  9.26,
#  7.83,
#  7.35,
#  8.32,
#  8.34,
#  8.83,
#  7.57,
#  7.35,
#  7.38,
#  7.8,
#  8.33,
#  8.08,
#  7.05,
#  7.19,
#  8.81,
#  7.67,
#  8.93,
#  7.93,
#  8.18,
#  7.26,
#  7.89,
#  8.4,
#  6.85,
#  8.03,
#  7.74,
#  8.74,
#  8.22,
#  7.59,
#  7.62,
#  7.75,
#  7.89,
#  7.69,
#  6.73,
#  8.27,
#  8.38,
#  7.62,
#  8.48,
#  7.66,
#  7.71,
#  7.78,
#  7.89,
#  7.95,
#  7.45,
#  8.47,
#  8.58,
#  8.14,
#  7.98,
#  7.04,
#  6.84,
#  7.74,
#  8.32,
#  8.03,
#  8.39,
#  7.45,
#  7.56,
#  8.17,
#  7.99,
#  7.76,
#  7.81,
#  7.03,
#  7.52,
#  7.46,
#  7.16,
#  7.64,
#  7.62,
#  7.14,
#  8.41,
#  8.3,
#  7.74,
#  8.44,
#  7.34,
#  7.93,
#  7.36,
#  7.56,
#  8.26,
#  8.14,
#  9.06,
#  7.34,
#  8.06,
#  7.18,
#  7.76,
#  9.26,
#  7.29,
#  7.22,
#  8.02,
#  7.55,
#  7.2,
#  8.37]

# %%
labeled_ratings.rating.tolist()
# Out:
# [10,
#  10,
#  10,
#  10,
#  10,
#  8,
#  6,
#  9,
#  10,
#  9,
#  6,
#  7,
#  7,
#  7,
#  10,
#  7,
#  7,
#  7,
#  8,
#  6,
#  8,
#  7,
#  10,
#  7,
#  8,
#  6,
#  8,
#  7,
#  7,
#  7,
#  8,
#  7,
#  10,
#  8,
#  7,
#  8,
#  6,
#  7,
#  6,
#  6,
#  7,
#  9,
#  8,
#  8,
#  10,
#  7,
#  8,
#  8,
#  6,
#  7,
#  9,
#  7,
#  10,
#  3,
#  8,
#  7,
#  8,
#  10,
#  10,
#  5,
#  7,
#  10,
#  8,
#  7,
#  7,
#  10,
#  7,
#  3,
#  9,
#  5,
#  10,
#  8,
#  9,
#  6,
#  7,
#  8,
#  8,
#  6,
#  6,
#  7,
#  8,
#  6,
#  4,
#  8,
#  10,
#  6,
#  8,
#  8,
#  9,
#  10,
#  6,
#  7,
#  9,
#  9,
#  6,
#  10,
#  7,
#  8,
#  6,
#  6,
#  6,
#  6,
#  5,
#  1,
#  1,
#  7,
#  8,
#  7,
#  1,
#  6,
#  6,
#  6,
#  8,
#  8,
#  6,
#  6,
#  2,
#  4,
#  6,
#  6,
#  5,
#  6,
#  6,
#  1,
#  1,
#  4,
#  8,
#  8,
#  6,
#  1,
#  3,
#  4,
#  1,
#  10,
#  1,
#  1,
#  5,
#  7,
#  8,
#  7,
#  7,
#  3,
#  5,
#  2,
#  7,
#  3,
#  7,
#  3,
#  6,
#  3,
#  7,
#  6,
#  4,
#  4,
#  3,
#  3,
#  5,
#  1,
#  3,
#  3,
#  6,
#  7,
#  7,
#  2,
#  7,
#  6,
#  2,
#  5,
#  5,
#  1,
#  2,
#  7,
#  4,
#  5,
#  1,
#  6,
#  7,
#  9,
#  5,
#  5,
#  2,
#  7,
#  5,
#  5,
#  1,
#  4,
#  7,
#  7,
#  7,
#  6,
#  5,
#  4,
#  5,
#  5,
#  5,
#  2,
#  2,
#  5,
#  7,
#  6,
#  1,
#  3,
#  8,
#  2,
#  3,
#  1,
#  5,
#  1,
#  7,
#  8,
#  5,
#  5,
#  6,
#  7,
#  7,
#  6,
#  9,
#  3,
#  5,
#  3,
#  8,
#  7,
#  6,
#  1,
#  5,
#  6,
#  6,
#  2,
#  7,
#  2,
#  1,
#  7,
#  5,
#  5,
#  9,
#  1,
#  7,
#  5,
#  1,
#  5,
#  2,
#  2,
#  3,
#  5,
#  3,
#  5,
#  6,
#  1,
#  1,
#  1,
#  5,
#  8,
#  1,
#  8,
#  8,
#  1,
#  2,
#  6,
#  2,
#  1,
#  6,
#  2,
#  5,
#  2,
#  8,
#  2,
#  5,
#  1,
#  7,
#  6,
#  2,
#  3,
#  5,
#  4,
#  7,
#  1,
#  3,
#  2,
#  6,
#  1,
#  1,
#  1,
#  8,
#  8,
#  5,
#  7,
#  7,
#  2,
#  2,
#  2,
#  1,
#  2,
#  3,
#  2,
#  1,
#  7,
#  4,
#  5,
#  1,
#  3,
#  2,
#  6,
#  1,
#  5,
#  2,
#  8,
#  1,
#  5,
#  9,
#  1,
#  1,
#  5,
#  1,
#  7,
#  2,
#  4,
#  2,
#  9,
#  5,
#  7,
#  1,
#  5,
#  3,
#  1,
#  3,
#  7,
#  7,
#  7,
#  1,
#  5,
#  6,
#  4,
#  1,
#  4,
#  4,
#  5,
#  7,
#  6,
#  5,
#  8,
#  3,
#  1,
#  7,
#  5,
#  1,
#  3,
#  5,
#  5,
#  9,
#  2,
#  7,
#  1,
#  3,
#  4,
#  3,
#  5,
#  8,
#  6,
#  7,
#  5,
#  8,
#  4,
#  4,
#  5,
#  2,
#  3,
#  5,
#  1,
#  5,
#  5,
#  1,
#  5,
#  5,
#  2,
#  2,
#  1,
#  6,
#  7,
#  1,
#  2,
#  3,
#  1,
#  2,
#  3,
#  1,
#  2,
#  6,
#  5,
#  7,
#  4,
#  7,
#  4,
#  9,
#  4,
#  2,
#  3,
#  3,
#  7,
#  6,
#  3,
#  5,
#  10,
#  5,
#  8,
#  5,
#  1,
#  4,
#  3,
#  1,
#  1,
#  8,
#  7,
#  7,
#  2,
#  5,
#  7,
#  1,
#  3,
#  5,
#  5,
#  5,
#  5,
#  2,
#  5,
#  7,
#  2,
#  5,
#  7,
#  1,
#  2,
#  8,
#  6,
#  2,
#  1,
#  2,
#  1,
#  1,
#  5,
#  4,
#  4,
#  2,
#  3,
#  7,
#  4,
#  5,
#  6,
#  5,
#  1,
#  2,
#  7,
#  2,
#  5,
#  4,
#  3,
#  8,
#  3,
#  1,
#  2,
#  2,
#  2,
#  7,
#  6,
#  5,
#  3,
#  8,
#  3,
#  1,
#  1,
#  4,
#  5,
#  1,
#  1,
#  3,
#  8,
#  7,
#  6,
#  1,
#  6,
#  1,
#  3,
#  8,
#  3,
#  7,
#  1,
#  3,
#  6,
#  3,
#  8,
#  1,
#  6,
#  5,
#  3,
#  1,
#  4,
#  5,
#  3,
#  6,
#  4,
#  3,
#  1,
#  3,
#  5,
#  3,
#  5,
#  3,
#  6,
#  6,
#  4,
#  2,
#  7,
#  8,
#  2,
#  7,
#  1,
#  7,
#  8,
#  4,
#  5,
#  1,
#  5,
#  7,
#  4,
#  5,
#  5,
#  4,
#  5,
#  6,
#  1,
#  4,
#  1,
#  2,
#  6,
#  2,
#  1,
#  7,
#  8,
#  6,
#  6,
#  2,
#  6,
#  5,
#  5,
#  2,
#  9,
#  5,
#  2,
#  1,
#  4,
#  2,
#  3,
#  8,
#  8,
#  8,
#  7,
#  9,
#  7,
#  7,
#  10,
#  9,
#  9,
#  7,
#  8,
#  7,
#  8,
#  8,
#  8,
#  7,
#  9,
#  9,
#  9,
#  7,
#  8,
#  8,
#  8,
#  9,
#  9,
#  8,
#  8,
#  8,
#  9,
#  7,
#  8,
#  8,
#  9,
#  8,
#  9,
#  8,
#  8,
#  9,
#  7,
#  9,
#  8,
#  8,
#  8,
#  7,
#  8,
#  7,
#  7,
#  8,
#  9,
#  8,
#  9,
#  7,
#  8,
#  9,
#  8,
#  9,
#  9,
#  8,
#  9,
#  9,
#  6,
#  9,
#  8,
#  9,
#  7,
#  8,
#  8,
#  7,
#  7,
#  8,
#  7,
#  8,
#  9,
#  8,
#  9,
#  9,
#  9,
#  7,
#  4,
#  7,
#  9,
#  10,
#  9,
#  8,
#  8,
#  8,
#  7,
#  8,
#  6,
#  8,
#  7,
#  8,
#  8,
#  7,
#  6,
#  7,
#  6,
#  7,
#  7,
#  7,
#  8,
#  8,
#  7,
#  7,
#  9,
#  7,
#  8,
#  8,
#  7,
#  7,
#  5,
#  8,
#  7,
#  7,
#  8,
#  7,
#  9,
#  8,
#  8,
#  7,
#  6,
#  7,
#  8,
#  7,
#  7,
#  7,
#  8,
#  8,
#  7,
#  6,
#  7,
#  9,
#  8,
#  6,
#  8,
#  8,
#  8,
#  8,
#  7,
#  8,
#  8,
#  8,
#  9,
#  7,
#  7,
#  8,
#  7,
#  7,
#  7,
#  5,
#  9,
#  7,
#  8,
#  7,
#  7,
#  6,
#  8,
#  10,
#  7,
#  7,
#  8,
#  7,
#  8,
#  7,
#  6,
#  8,
#  7,
#  8,
#  7,
#  5,
#  7,
#  6,
#  6,
#  8,
#  9,
#  7,
#  4,
#  8,
#  9,
#  6,
#  7,
#  7,
#  10,
#  7,
#  9,
#  7,
#  7,
#  7,
#  8,
#  7,
#  8,
#  5,
#  7,
#  7,
#  7,
#  7,
#  8,
#  8,
#  8,
#  8,
#  8,
#  6,
#  6,
#  8,
#  7,
#  7,
#  8,
#  6,
#  8,
#  7,
#  5,
#  6,
#  8,
#  5,
#  10,
#  7,
#  5,
#  8,
#  6,
#  7,
#  8,
#  10,
#  6,
#  8,
#  8,
#  7,
#  6,
#  9,
#  7,
#  6,
#  7,
#  8,
#  8,
#  8,
#  8,
#  9,
#  6,
#  7,
#  5,
#  7,
#  8,
#  7,
#  6,
#  7,
#  7,
#  8,
#  6,
#  7,
#  7,
#  7,
#  7,
#  7,
#  8,
#  7,
#  8,
#  9,
#  7,
#  8,
#  5,
#  7,
#  6,
#  6,
#  8,
#  6,
#  8,
#  7,
#  8,
#  7,
#  8,
#  8,
#  5,
#  7,
#  8,
#  8,
#  8,
#  8,
#  8,
#  6,
#  7,
#  7,
#  8,
#  6,
#  8,
#  7,
#  6,
#  8,
#  7,
#  6,
#  9,
#  8,
#  6,
#  7,
#  7,
#  6,
#  7,
#  7,
#  7,
#  8,
#  8,
#  5,
#  6,
#  8,
#  8,
#  8,
#  7,
#  6,
#  7,
#  8,
#  7,
#  7,
#  5,
#  7,
#  8,
#  8,
#  8,
#  7,
#  8,
#  7,
#  7,
#  9,
#  8,
#  7,
#  6,
#  7,
#  5,
#  5,
#  7,
#  5,
#  7,
#  8,
#  8,
#  7,
#  5,
#  7,
#  7,
#  6,
#  6,
#  7,
#  6,
#  8,
#  7,
#  5,
#  7,
#  7,
#  4,
#  5,
#  8,
#  7,
#  9,
#  9,
#  10,
#  5,
#  9,
#  8,
#  6,
#  10,
#  7,
#  9,
#  9,
#  9,
#  8,
#  10,
#  9,
#  9,
#  5,
#  7,
#  7,
#  7,
#  4,
#  9,
#  6,
#  7,
#  6,
#  7,
#  5,
#  8,
#  7,
#  10,
#  9,
#  6,
#  4,
#  9,
#  10,
#  7,
#  10,
#  6,
#  8,
#  10,
#  9,
#  6,
#  7,
#  6,
#  9,
#  7,
#  5,
#  9,
#  7,
#  8,
#  7,
#  7,
#  7,
#  7,
#  6,
#  6,
#  7,
#  10,
#  9,
#  7,
#  4,
#  7,
#  7,
#  8,
#  8,
#  7,
#  6,
#  7,
#  8,
#  7,
#  7,
#  7,
#  8,
#  8,
#  9,
#  8,
#  7,
#  7,
#  6,
#  8,
#  7,
#  10,
#  6,
#  6,
#  6,
#  6,
#  6,
#  9,
#  7,
#  8,
#  6,
#  6,
#  6,
#  7,
#  8,
#  6,
#  7,
#  9,
#  4,
#  7,
#  8]
